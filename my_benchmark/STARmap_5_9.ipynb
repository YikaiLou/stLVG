# %%
import time
from pathlib import Path
from operator import itemgetter

import scanpy as sc
import numpy as np
import pandas as pd
from sklearn.metrics import adjusted_rand_score, normalized_mutual_info_score
from scipy.sparse import csr_matrix
from joblib import Parallel, delayed
import os
import torch

import scSLAT
from scSLAT.model import Cal_Spatial_Net, load_anndatas, run_SLAT_mlp_AGF, spatial_match, run_SLAT, compute_lisi_for_adata, run_SLAT_AGF_contrast
from scSLAT.viz import match_3D_multi, hist, Sankey, build_3D
from scSLAT.metrics import region_statistics

# %%
adata_1=sc.read_h5ad(r'D:\ppppaper\data\STARmap\20180419_BZ9_control.h5ad')
adata_1.var_names_make_unique(join="++")
adata_1
# Out:
# AnnData object with n_obs × n_vars = 1053 × 166
#     obs: 'ct', 'region', 'Region', 'ground_truth'
#     uns: 'ct_colors', 'region_colors'
#     obsm: 'spatial'

# %%
adata_2=sc.read_h5ad(r'D:\ppppaper\data\STARmap\20180417_BZ5_control.h5ad')
adata_2.var_names_make_unique(join="++")
adata_2
# Out:
# AnnData object with n_obs × n_vars = 1049 × 166
#     obs: 'ct', 'region', 'Region', 'ground_truth'
#     uns: 'ct_colors', 'region_colors'
#     obsm: 'spatial'

# %%
x1_coords=adata_1.obsm['spatial'][:,0]
y1_coords=adata_1.obsm['spatial'][:,1]
x2_coords=adata_2.obsm['spatial'][:,0]
y2_coords=adata_2.obsm['spatial'][:,1]
locations_1 = np.array([x1_coords, y1_coords])
locations_2 = np.array([x2_coords, y2_coords])

locations_1_tensor = torch.tensor(locations_1)
locations_2_tensor = torch.tensor(locations_2)
locations_1_tensor = locations_1_tensor.transpose(0, 1)
locations_1_tensor = locations_1_tensor.to(dtype=torch.float32)
locations_2_tensor = locations_2_tensor.transpose(0, 1)
locations_2_tensor = locations_2_tensor.to(dtype=torch.float32)
location = [locations_1_tensor, locations_2_tensor]

# %%
Cal_Spatial_Net(adata_1, k_cutoff=10, model='KNN')
Cal_Spatial_Net(adata_2, k_cutoff=10, model='KNN')
# Out:
# Calculating spatial neighbor graph ...
# The graph contains 11899 edges, 1053 cells.
# 11.300094966761634 neighbors per cell on average.
# Calculating spatial neighbor graph ...
# The graph contains 11881 edges, 1049 cells.
# 11.32602478551001 neighbors per cell on average.

# %%
edges, features = load_anndatas([adata_1, adata_2], feature='DPCA')
# Out:
# Use DPCA feature to format graph
# d:\Anaconda\envs\scSLAT\lib\site-packages\anndata\_core\anndata.py:1763: FutureWarning: The AnnData.concatenate method is deprecated in favour of the anndata.concat function. Please use anndata.concat instead.
#
# See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   warnings.warn(
# d:\Anaconda\envs\scSLAT\lib\site-packages\scanpy\preprocessing\_normalization.py:169: UserWarning: Received a view of an AnnData. Making a copy.
#   view_to_actual(adata)
# d:\Anaconda\envs\scSLAT\lib\site-packages\scanpy\preprocessing\_simple.py:843: UserWarning: Received a view of an AnnData. Making a copy.
#   view_to_actual(adata)
# d:\Anaconda\envs\scSLAT\lib\site-packages\scanpy\preprocessing\_simple.py:843: UserWarning: Received a view of an AnnData. Making a copy.
#   view_to_actual(adata)

# %%
embd0_0, embd0_1, embd1_0, embd1_1, embd0, embd1, time = run_SLAT_AGF_contrast(features, edges, location, limit_loss=0.001)
# Out:
# GPU is not available
# Running
# ---------- epochs: 1 ----------
# ---- Ran row_normalize in 0.00 s ----
#
# ---- Ran row_normalize in 0.01 s ----
#
# ---------- epochs: 2 ----------
# ---- Ran row_normalize in 0.01 s ----
#
# ---- Ran row_normalize in 0.01 s ----
#
# ---------- epochs: 3 ----------
# ---- Ran row_normalize in 0.01 s ----
#
# ---- Ran row_normalize in 0.01 s ----
#
# ---------- epochs: 4 ----------
# ---- Ran row_normalize in 0.01 s ----
#
# ---- Ran row_normalize in 0.01 s ----
#
# ---------- epochs: 5 ----------
# ---- Ran row_normalize in 0.01 s ----
#
# ---- Ran row_normalize in 0.01 s ----
#
# ---------- epochs: 6 ----------
# ---- Ran row_normalize in 0.01 s ----
#
# ---- Ran row_normalize in 0.01 s ----
#
# ---- Ran row_normalize in 0.00 s ----
#
# ---- Ran row_normalize in 0.00 s ----
#
# ---------- epochs: 1 ----------
# ---- Ran row_normalize in 0.01 s ----
#
# ---- Ran row_normalize in 0.01 s ----
#
# ---------- epochs: 2 ----------
# ---- Ran row_normalize in 0.01 s ----
#
# ---- Ran row_normalize in 0.01 s ----
#
# ---------- epochs: 3 ----------
# ---- Ran row_normalize in 0.01 s ----
#
# ---- Ran row_normalize in 0.01 s ----
#
# ---------- epochs: 4 ----------
# ---- Ran row_normalize in 0.01 s ----
#
# ---- Ran row_normalize in 0.01 s ----
#
# ---------- epochs: 5 ----------
# ---- Ran row_normalize in 0.01 s ----
#
# ---- Ran row_normalize in 0.01 s ----
#
# ---------- epochs: 6 ----------
# ---- Ran row_normalize in 0.00 s ----
#
# ---- Ran row_normalize in 0.01 s ----
#
# ---- Ran row_normalize in 0.00 s ----
#
# ---- Ran row_normalize in 0.00 s ----
#
# ---------- Combined epochs: 0 ----------
# Contrastive Loss 0: 4.5420427322387695
# Contrastive Loss 1: 4.535897254943848
# Total Combined Loss: 9.077939987182617
# ---------- Combined epochs: 1 ----------
# Contrastive Loss 0: 3.8770720958709717
# Contrastive Loss 1: 3.892662286758423
# Total Combined Loss: 7.7697343826293945
# ---------- Combined epochs: 2 ----------
# Contrastive Loss 0: 3.804389476776123
# Contrastive Loss 1: 3.8166184425354004
# Total Combined Loss: 7.621007919311523
# ---------- Combined epochs: 3 ----------
# Contrastive Loss 0: 3.75705885887146
# Contrastive Loss 1: 3.770777940750122
# Total Combined Loss: 7.527836799621582
# ---------- Combined epochs: 4 ----------
# Contrastive Loss 0: 3.717731475830078
# Contrastive Loss 1: 3.730100631713867
# Total Combined Loss: 7.447832107543945
# ---------- Combined epochs: 5 ----------
# Contrastive Loss 0: 3.6914360523223877
# Contrastive Loss 1: 3.6995325088500977
# Total Combined Loss: 7.390968322753906
# ---------- Combined epochs: 6 ----------
# Contrastive Loss 0: 3.6723806858062744
# Contrastive Loss 1: 3.6744801998138428
# Total Combined Loss: 7.346860885620117
# ---------- Combined epochs: 7 ----------
# Contrastive Loss 0: 3.6588029861450195
# Contrastive Loss 1: 3.6546175479888916
# Total Combined Loss: 7.313420295715332
# ---------- Combined epochs: 8 ----------
# Contrastive Loss 0: 3.649311065673828
# Contrastive Loss 1: 3.6398909091949463
# Total Combined Loss: 7.289201736450195
# ---------- Combined epochs: 9 ----------
# Contrastive Loss 0: 3.6404459476470947
# Contrastive Loss 1: 3.627383232116699
# Total Combined Loss: 7.267828941345215
# ---------- Combined epochs: 10 ----------
# Contrastive Loss 0: 3.6305575370788574
# Contrastive Loss 1: 3.6154532432556152
# Total Combined Loss: 7.246010780334473
# ---------- Combined epochs: 11 ----------
# Contrastive Loss 0: 3.620035171508789
# Contrastive Loss 1: 3.6041605472564697
# Total Combined Loss: 7.22419548034668
# ---------- Combined epochs: 12 ----------
# Contrastive Loss 0: 3.609668731689453
# Contrastive Loss 1: 3.593799352645874
# Total Combined Loss: 7.203468322753906
# ---------- Combined epochs: 13 ----------
# Contrastive Loss 0: 3.5999717712402344
# Contrastive Loss 1: 3.5844194889068604
# Total Combined Loss: 7.184391021728516
# ---------- Combined epochs: 14 ----------
# Contrastive Loss 0: 3.5911943912506104
# Contrastive Loss 1: 3.5759694576263428
# Total Combined Loss: 7.167163848876953
# ---------- Combined epochs: 15 ----------
# Contrastive Loss 0: 3.583360195159912
# Contrastive Loss 1: 3.5683751106262207
# Total Combined Loss: 7.151735305786133
# ---------- Combined epochs: 16 ----------
# Contrastive Loss 0: 3.5762879848480225
# Contrastive Loss 1: 3.5615029335021973
# Total Combined Loss: 7.137790679931641
# ---------- Combined epochs: 17 ----------
# Contrastive Loss 0: 3.5697073936462402
# Contrastive Loss 1: 3.5551788806915283
# Total Combined Loss: 7.124886512756348
# ---------- Combined epochs: 18 ----------
# Contrastive Loss 0: 3.5634043216705322
# Contrastive Loss 1: 3.549255847930908
# Total Combined Loss: 7.1126604080200195
# ---------- Combined epochs: 19 ----------
# Contrastive Loss 0: 3.5572824478149414
# Contrastive Loss 1: 3.5436367988586426
# Total Combined Loss: 7.100919246673584
# ---------- Combined epochs: 20 ----------
# Contrastive Loss 0: 3.551335573196411
# Contrastive Loss 1: 3.5382654666900635
# Total Combined Loss: 7.089601039886475
# ---------- Combined epochs: 21 ----------
# Contrastive Loss 0: 3.5456154346466064
# Contrastive Loss 1: 3.5331103801727295
# Total Combined Loss: 7.078725814819336
# ---------- Combined epochs: 22 ----------
# Contrastive Loss 0: 3.540189504623413
# Contrastive Loss 1: 3.5281624794006348
# Total Combined Loss: 7.068351745605469
# ---------- Combined epochs: 23 ----------
# Contrastive Loss 0: 3.5351028442382812
# Contrastive Loss 1: 3.5234055519104004
# Total Combined Loss: 7.058508396148682
# ---------- Combined epochs: 24 ----------
# Contrastive Loss 0: 3.5303351879119873
# Contrastive Loss 1: 3.5187878608703613
# Total Combined Loss: 7.0491228103637695
# ---------- Combined epochs: 25 ----------
# Contrastive Loss 0: 3.525789976119995
# Contrastive Loss 1: 3.5142154693603516
# Total Combined Loss: 7.040005683898926
# ---------- Combined epochs: 26 ----------
# Contrastive Loss 0: 3.521345615386963
# Contrastive Loss 1: 3.509601593017578
# Total Combined Loss: 7.030947208404541
# ---------- Combined epochs: 27 ----------
# Contrastive Loss 0: 3.5169363021850586
# Contrastive Loss 1: 3.504915714263916
# Total Combined Loss: 7.021852016448975
# ---------- Combined epochs: 28 ----------
# Contrastive Loss 0: 3.5125741958618164
# Contrastive Loss 1: 3.500201940536499
# Total Combined Loss: 7.0127763748168945
# ---------- Combined epochs: 29 ----------
# Contrastive Loss 0: 3.508314609527588
# Contrastive Loss 1: 3.495526075363159
# Total Combined Loss: 7.003840446472168
# ---------- Combined epochs: 30 ----------
# Contrastive Loss 0: 3.504188299179077
# Contrastive Loss 1: 3.4909188747406006
# Total Combined Loss: 6.995107173919678
# ---------- Combined epochs: 31 ----------
# Contrastive Loss 0: 3.5001704692840576
# Contrastive Loss 1: 3.486353635787964
# Total Combined Loss: 6.9865241050720215
# ---------- Combined epochs: 32 ----------
# Contrastive Loss 0: 3.4962048530578613
# Contrastive Loss 1: 3.481783866882324
# Total Combined Loss: 6.9779887199401855
# ---------- Combined epochs: 33 ----------
# Contrastive Loss 0: 3.4922523498535156
# Contrastive Loss 1: 3.4771828651428223
# Total Combined Loss: 6.969435214996338
# ---------- Combined epochs: 34 ----------
# Contrastive Loss 0: 3.4882936477661133
# Contrastive Loss 1: 3.472557544708252
# Total Combined Loss: 6.960851192474365
# ---------- Combined epochs: 35 ----------
# Contrastive Loss 0: 3.4843108654022217
# Contrastive Loss 1: 3.4679179191589355
# Total Combined Loss: 6.952228546142578
# ---------- Combined epochs: 36 ----------
# Contrastive Loss 0: 3.480276584625244
# Contrastive Loss 1: 3.4632606506347656
# Total Combined Loss: 6.94353723526001
# ---------- Combined epochs: 37 ----------
# Contrastive Loss 0: 3.476168155670166
# Contrastive Loss 1: 3.458580732345581
# Total Combined Loss: 6.934748649597168
# ---------- Combined epochs: 38 ----------
# Contrastive Loss 0: 3.4719974994659424
# Contrastive Loss 1: 3.4538891315460205
# Total Combined Loss: 6.925886631011963
# ---------- Combined epochs: 39 ----------
# Contrastive Loss 0: 3.4677963256835938
# Contrastive Loss 1: 3.449214220046997
# Total Combined Loss: 6.917010307312012
# ---------- Combined epochs: 40 ----------
# Contrastive Loss 0: 3.4635915756225586
# Contrastive Loss 1: 3.444561004638672
# Total Combined Loss: 6.9081525802612305
# ---------- Combined epochs: 41 ----------
# Contrastive Loss 0: 3.4593803882598877
# Contrastive Loss 1: 3.4399075508117676
# Total Combined Loss: 6.899288177490234
# ---------- Combined epochs: 42 ----------
# Contrastive Loss 0: 3.4551496505737305
# Contrastive Loss 1: 3.435230016708374
# Total Combined Loss: 6.890379905700684
# ---------- Combined epochs: 43 ----------
# Contrastive Loss 0: 3.4509048461914062
# Contrastive Loss 1: 3.4305272102355957
# Total Combined Loss: 6.881432056427002
# ---------- Combined epochs: 44 ----------
# Contrastive Loss 0: 3.4466629028320312
# Contrastive Loss 1: 3.425814390182495
# Total Combined Loss: 6.8724775314331055
# ---------- Combined epochs: 45 ----------
# Contrastive Loss 0: 3.442408800125122
# Contrastive Loss 1: 3.4210891723632812
# Total Combined Loss: 6.863497734069824
# ---------- Combined epochs: 46 ----------
# Contrastive Loss 0: 3.438102960586548
# Contrastive Loss 1: 3.416337013244629
# Total Combined Loss: 6.854439735412598
# ---------- Combined epochs: 47 ----------
# Contrastive Loss 0: 3.4337286949157715
# Contrastive Loss 1: 3.4115710258483887
# Total Combined Loss: 6.84529972076416
# ---------- Combined epochs: 48 ----------
# Contrastive Loss 0: 3.429299831390381
# Contrastive Loss 1: 3.4068403244018555
# Total Combined Loss: 6.836140155792236
# ---------- Combined epochs: 49 ----------
# Contrastive Loss 0: 3.424811601638794
# Contrastive Loss 1: 3.402163505554199
# Total Combined Loss: 6.826974868774414
# ---------- Combined epochs: 50 ----------
# Contrastive Loss 0: 3.420225143432617
# Contrastive Loss 1: 3.397519111633301
# Total Combined Loss: 6.817744255065918
# ---------- Combined epochs: 51 ----------
# Contrastive Loss 0: 3.4155218601226807
# Contrastive Loss 1: 3.392881155014038
# Total Combined Loss: 6.808403015136719
# ---------- Combined epochs: 52 ----------
# Contrastive Loss 0: 3.4107251167297363
# Contrastive Loss 1: 3.388237237930298
# Total Combined Loss: 6.798962593078613
# ---------- Combined epochs: 53 ----------
# Contrastive Loss 0: 3.405863046646118
# Contrastive Loss 1: 3.383559226989746
# Total Combined Loss: 6.789422035217285
# ---------- Combined epochs: 54 ----------
# Contrastive Loss 0: 3.4009549617767334
# Contrastive Loss 1: 3.378821611404419
# Total Combined Loss: 6.779776573181152
# ---------- Combined epochs: 55 ----------
# Contrastive Loss 0: 3.3960318565368652
# Contrastive Loss 1: 3.374051809310913
# Total Combined Loss: 6.770083427429199
# ---------- Combined epochs: 56 ----------
# Contrastive Loss 0: 3.391092300415039
# Contrastive Loss 1: 3.369284152984619
# Total Combined Loss: 6.760376453399658
# ---------- Combined epochs: 57 ----------
# Contrastive Loss 0: 3.3860812187194824
# Contrastive Loss 1: 3.364522695541382
# Total Combined Loss: 6.750603675842285
# ---------- Combined epochs: 58 ----------
# Contrastive Loss 0: 3.380978584289551
# Contrastive Loss 1: 3.35977840423584
# Total Combined Loss: 6.740756988525391
# ---------- Combined epochs: 59 ----------
# Contrastive Loss 0: 3.3758163452148438
# Contrastive Loss 1: 3.355048894882202
# Total Combined Loss: 6.730865478515625
# ---------- Combined epochs: 60 ----------
# Contrastive Loss 0: 3.3706188201904297
# Contrastive Loss 1: 3.350290298461914
# Total Combined Loss: 6.720909118652344
# ---------- Combined epochs: 61 ----------
# Contrastive Loss 0: 3.3654091358184814
# Contrastive Loss 1: 3.3454833030700684
# Total Combined Loss: 6.710892677307129
# ---------- Combined epochs: 62 ----------
# Contrastive Loss 0: 3.360175371170044
# Contrastive Loss 1: 3.340646982192993
# Total Combined Loss: 6.700822353363037
# ---------- Combined epochs: 63 ----------
# Contrastive Loss 0: 3.3548717498779297
# Contrastive Loss 1: 3.3358047008514404
# Total Combined Loss: 6.690676689147949
# ---------- Combined epochs: 64 ----------
# Contrastive Loss 0: 3.3495097160339355
# Contrastive Loss 1: 3.3309812545776367
# Total Combined Loss: 6.680490970611572
# ---------- Combined epochs: 65 ----------
# Contrastive Loss 0: 3.3441426753997803
# Contrastive Loss 1: 3.3261587619781494
# Total Combined Loss: 6.67030143737793
# ---------- Combined epochs: 66 ----------
# Contrastive Loss 0: 3.3387856483459473
# Contrastive Loss 1: 3.321286916732788
# Total Combined Loss: 6.660072326660156
# ---------- Combined epochs: 67 ----------
# Contrastive Loss 0: 3.333397388458252
# Contrastive Loss 1: 3.3163504600524902
# Total Combined Loss: 6.649747848510742
# ---------- Combined epochs: 68 ----------
# Contrastive Loss 0: 3.3279612064361572
# Contrastive Loss 1: 3.3113720417022705
# Total Combined Loss: 6.639333248138428
# ---------- Combined epochs: 69 ----------
# Contrastive Loss 0: 3.3225173950195312
# Contrastive Loss 1: 3.3063387870788574
# Total Combined Loss: 6.628856182098389
# ---------- Combined epochs: 70 ----------
# Contrastive Loss 0: 3.317105531692505
# Contrastive Loss 1: 3.301224946975708
# Total Combined Loss: 6.618330478668213
# ---------- Combined epochs: 71 ----------
# Contrastive Loss 0: 3.31169056892395
# Contrastive Loss 1: 3.2960493564605713
# Total Combined Loss: 6.6077399253845215
# ---------- Combined epochs: 72 ----------
# Contrastive Loss 0: 3.3062379360198975
# Contrastive Loss 1: 3.290858268737793
# Total Combined Loss: 6.5970964431762695
# ---------- Combined epochs: 73 ----------
# Contrastive Loss 0: 3.3007822036743164
# Contrastive Loss 1: 3.2856223583221436
# Total Combined Loss: 6.586404800415039
# ---------- Combined epochs: 74 ----------
# Contrastive Loss 0: 3.2953760623931885
# Contrastive Loss 1: 3.280308961868286
# Total Combined Loss: 6.575685024261475
# ---------- Combined epochs: 75 ----------
# Contrastive Loss 0: 3.290015459060669
# Contrastive Loss 1: 3.2749624252319336
# Total Combined Loss: 6.564977645874023
# ---------- Combined epochs: 76 ----------
# Contrastive Loss 0: 3.2846879959106445
# Contrastive Loss 1: 3.269578695297241
# Total Combined Loss: 6.554266929626465
# ---------- Combined epochs: 77 ----------
# Contrastive Loss 0: 3.279407262802124
# Contrastive Loss 1: 3.2641470432281494
# Total Combined Loss: 6.543554306030273
# ---------- Combined epochs: 78 ----------
# Contrastive Loss 0: 3.274122476577759
# Contrastive Loss 1: 3.2587647438049316
# Total Combined Loss: 6.5328874588012695
# ---------- Combined epochs: 79 ----------
# Contrastive Loss 0: 3.2687997817993164
# Contrastive Loss 1: 3.2534067630767822
# Total Combined Loss: 6.5222063064575195
# ---------- Combined epochs: 80 ----------
# Contrastive Loss 0: 3.2635183334350586
# Contrastive Loss 1: 3.247994899749756
# Total Combined Loss: 6.5115132331848145
# ---------- Combined epochs: 81 ----------
# Contrastive Loss 0: 3.2582409381866455
# Contrastive Loss 1: 3.242586135864258
# Total Combined Loss: 6.500826835632324
# ---------- Combined epochs: 82 ----------
# Contrastive Loss 0: 3.252931833267212
# Contrastive Loss 1: 3.237211227416992
# Total Combined Loss: 6.490142822265625
# ---------- Combined epochs: 83 ----------
# Contrastive Loss 0: 3.2476773262023926
# Contrastive Loss 1: 3.2318027019500732
# Total Combined Loss: 6.479479789733887
# ---------- Combined epochs: 84 ----------
# Contrastive Loss 0: 3.2424237728118896
# Contrastive Loss 1: 3.2264208793640137
# Total Combined Loss: 6.468844413757324
# ---------- Combined epochs: 85 ----------
# Contrastive Loss 0: 3.237330436706543
# Contrastive Loss 1: 3.2210724353790283
# Total Combined Loss: 6.458402633666992
# ---------- Combined epochs: 86 ----------
# Contrastive Loss 0: 3.2333052158355713
# Contrastive Loss 1: 3.216464042663574
# Total Combined Loss: 6.449769020080566
# ---------- Combined epochs: 87 ----------
# Contrastive Loss 0: 3.2378897666931152
# Contrastive Loss 1: 3.221189260482788
# Total Combined Loss: 6.459078788757324
# ---------- Combined epochs: 88 ----------
# Contrastive Loss 0: 3.2745344638824463
# Contrastive Loss 1: 3.2574172019958496
# Total Combined Loss: 6.531951904296875
# ---------- Combined epochs: 89 ----------
# Contrastive Loss 0: 3.2340786457061768
# Contrastive Loss 1: 3.2157154083251953
# Total Combined Loss: 6.449793815612793
# ---------- Combined epochs: 90 ----------
# Contrastive Loss 0: 3.237618923187256
# Contrastive Loss 1: 3.217430353164673
# Total Combined Loss: 6.455049514770508
# ---------- Combined epochs: 91 ----------
# Contrastive Loss 0: 3.2491495609283447
# Contrastive Loss 1: 3.229586601257324
# Total Combined Loss: 6.47873592376709
# ---------- Combined epochs: 92 ----------
# Contrastive Loss 0: 3.222830295562744
# Contrastive Loss 1: 3.2026636600494385
# Total Combined Loss: 6.425494194030762
# ---------- Combined epochs: 93 ----------
# Contrastive Loss 0: 3.245737075805664
# Contrastive Loss 1: 3.2260756492614746
# Total Combined Loss: 6.471812725067139
# ---------- Combined epochs: 94 ----------
# Contrastive Loss 0: 3.2118611335754395
# Contrastive Loss 1: 3.191800594329834
# Total Combined Loss: 6.403661727905273
# ---------- Combined epochs: 95 ----------
# Contrastive Loss 0: 3.223762273788452
# Contrastive Loss 1: 3.204282283782959
# Total Combined Loss: 6.428044319152832
# ---------- Combined epochs: 96 ----------
# Contrastive Loss 0: 3.2020020484924316
# Contrastive Loss 1: 3.1811647415161133
# Total Combined Loss: 6.383166790008545
# ---------- Combined epochs: 97 ----------
# Contrastive Loss 0: 3.214278221130371
# Contrastive Loss 1: 3.194260597229004
# Total Combined Loss: 6.408538818359375
# ---------- Combined epochs: 98 ----------
# Contrastive Loss 0: 3.195199966430664
# Contrastive Loss 1: 3.1761796474456787
# Total Combined Loss: 6.371379852294922
# ---------- Combined epochs: 99 ----------
# Contrastive Loss 0: 3.1996169090270996
# Contrastive Loss 1: 3.179694414138794
# Total Combined Loss: 6.379311561584473
# ---------- Combined epochs: 100 ----------
# Contrastive Loss 0: 3.1875672340393066
# Contrastive Loss 1: 3.167651414871216
# Total Combined Loss: 6.355218887329102
# ---------- Combined epochs: 101 ----------
# Contrastive Loss 0: 3.191490650177002
# Contrastive Loss 1: 3.1708459854125977
# Total Combined Loss: 6.3623366355896
# ---------- Combined epochs: 102 ----------
# Contrastive Loss 0: 3.1803624629974365
# Contrastive Loss 1: 3.159668445587158
# Total Combined Loss: 6.340030670166016
# ---------- Combined epochs: 103 ----------
# Contrastive Loss 0: 3.1800873279571533
# Contrastive Loss 1: 3.159393310546875
# Total Combined Loss: 6.339480400085449
# Training stopped at epoch: 103

# %%
adata_1.obsm['scSLAT_bks'] = embd0.detach().cpu().numpy()
adata_2.obsm['scSLAT_bks'] = embd1.detach().cpu().numpy()
adata_com = sc.concat([adata_1, adata_2], label='slice_name', keys=['slice_1', 'slice_2'])

sc.pp.neighbors(adata_com, use_rep= 'scSLAT_bks')
sc.tl.umap(adata_com)

# %%
sc.pl.umap(adata_com, color= ['slice_name', 'ground_truth'])
# Out:
# d:\Anaconda\envs\scSLAT\lib\site-packages\scanpy\plotting\_tools\scatterplots.py:394: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(
# d:\Anaconda\envs\scSLAT\lib\site-packages\scanpy\plotting\_tools\scatterplots.py:394: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(

# %%
# LISI
lisi_scores = compute_lisi_for_adata(adata_com, obsm_key='scSLAT_bks', obs_key_list=['ground_truth', 'slice_name'])
print("LISI Scores:\n", lisi_scores)
# Out:
# LISI Scores:
#  {'cLISI': 1.1233220645208752, 'iLISI': 1.6461862938013174}

# %%
true_labels_1 = adata_1.obs['ground_truth'].to_numpy()
true_labels_2 = adata_2.obs['ground_truth'].to_numpy()

best, index, distance = spatial_match([embd0, embd1], adatas=[adata_1, adata_2], reorder=False)
valid_indices = best < true_labels_1.size
valid_best = best[valid_indices]
valid_indices = np.arange(len(best))[valid_indices] 

aligned_true_labels_1 = true_labels_1[valid_best]
matched_labels_3 = true_labels_2[valid_indices]

# 计算 ARI 和 NMI
ari = adjusted_rand_score(aligned_true_labels_1, matched_labels_3)
nmi = normalized_mutual_info_score(aligned_true_labels_1, matched_labels_3)

print(f'ARI: {ari}, NMI: {nmi}')
# Out:
# ARI: 0.8557768243104596, NMI: 0.8132211944300821

# %%
embd2, embd3, time = run_SLAT(features, edges)
# Out:
# GPU is not available
# Running
# ---------- epochs: 1 ----------
# ---------- epochs: 2 ----------
# ---------- epochs: 3 ----------
# ---------- epochs: 4 ----------
# ---------- epochs: 5 ----------
# ---------- epochs: 6 ----------
# Training model time: 8.25

# %%
adata_1.obsm['scSLAT'] = embd2.detach().cpu().numpy()
adata_2.obsm['scSLAT'] = embd3.detach().cpu().numpy()
adata_com_2 = sc.concat([adata_1,adata_2], label= 'slice_name', keys= ['slice_1','slice_2'])

sc.pp.neighbors(adata_com_2, use_rep= 'scSLAT')
sc.tl.umap(adata_com_2)

# %%
sc.pl.umap(adata_com_2, color= ['slice_name', 'ground_truth'])
# Out:
# d:\Anaconda\envs\scSLAT\lib\site-packages\scanpy\plotting\_tools\scatterplots.py:394: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(
# d:\Anaconda\envs\scSLAT\lib\site-packages\scanpy\plotting\_tools\scatterplots.py:394: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(

# %%
true_labels_1 = adata_1.obs['ground_truth'].to_numpy()
true_labels_2 = adata_2.obs['ground_truth'].to_numpy()

best_2, index_2, distance_2 = spatial_match([embd2, embd3], adatas=[adata_1, adata_2], reorder=False)
valid_indices = best_2 < true_labels_1.size
valid_best = best_2[valid_indices]
valid_indices = np.arange(len(best_2))[valid_indices] 

aligned_true_labels_1 = true_labels_1[valid_best]
matched_labels_3 = true_labels_2[valid_indices]

# 计算 ARI 和 NMI
ari = adjusted_rand_score(aligned_true_labels_1, matched_labels_3)
nmi = normalized_mutual_info_score(aligned_true_labels_1, matched_labels_3)

print(f'ARI: {ari}, NMI: {nmi}')
# Out:
# ARI: 0.6939107753067317, NMI: 0.6441345500584884

# %%
lisi_scores_2 = compute_lisi_for_adata(adata_com_2, obsm_key='scSLAT', obs_key_list=['ground_truth', 'slice_name'])
print("LISI Scores:\n", lisi_scores_2)
# Out:
# LISI Scores:
#  {'cLISI': 1.5752743605405863, 'iLISI': 1.8369720221185457}

# %%
adata1_df = pd.DataFrame({'index': range(embd0.shape[0]),
                        'x': adata_1.obsm['spatial'][:,0],
                        'y': adata_1.obsm['spatial'][:,1],
                        'celltype': adata_1.obs['ground_truth']})
adata2_df = pd.DataFrame({'index': range(embd1.shape[0]),
                        'x': adata_2.obsm['spatial'][:,0],
                        'y': adata_2.obsm['spatial'][:,1],
                        'celltype': adata_2.obs['ground_truth']})

matching = np.array([range(index.shape[0]), best])
best_match = distance[:,0]

# %%
adata3_df = pd.DataFrame({'index': range(embd2.shape[0]),
                        'x': adata_1.obsm['spatial'][:,0],
                        'y': adata_1.obsm['spatial'][:,1],
                        'celltype': adata_1.obs['ground_truth']})
adata4_df = pd.DataFrame({'index': range(embd3.shape[0]),
                        'x': adata_2.obsm['spatial'][:,0],
                        'y': adata_2.obsm['spatial'][:,1],
                        'celltype': adata_2.obs['ground_truth']})

matching_2 = np.array([range(index.shape[0]), best_2])
best_match_2 = distance_2[:,0]

# %%
adata2_df['target_celltype'] = adata1_df.iloc[matching[1,:],:]['celltype'].to_list()
matching_table = adata2_df.groupby(['celltype','target_celltype']).size().unstack(fill_value=0)

# %%
adata4_df['target_celltype'] = adata3_df.iloc[matching_2[1,:],:]['celltype'].to_list()
matching_table_2 = adata4_df.groupby(['celltype','target_celltype']).size().unstack(fill_value=0)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

custom_cmap = sns.color_palette("light:purple", as_cmap=True)

sns.heatmap(matching_table, annot = True, fmt = "d", cmap = custom_cmap)
plt.title('Matching Table Heatmap')
plt.xlabel('Target Cell Type')
plt.ylabel('Cell Type')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

custom_cmap = sns.color_palette("light:purple", as_cmap=True)

sns.heatmap(matching_table_2, annot = True, fmt = "d", cmap = custom_cmap)
plt.title('Matching Table Heatmap')
plt.xlabel('Target Cell Type')
plt.ylabel('Cell Type')
plt.show()

# %%
correct_matches = 0
total_matches = 0

for i, row in matching_table.iterrows():
    if i in matching_table.columns and row[i] > 0:
        correct_matches += row[i]
    total_matches += row.sum()


accuracy = correct_matches / total_matches if total_matches > 0 else 0
correct_matches,total_matches,accuracy
# Out:
# (992, 1049, 0.9456625357483317)

# %%
correct_matches = 0
total_matches = 0

for i, row in matching_table_2.iterrows():
    if i in matching_table_2.columns and row[i] > 0:
        correct_matches += row[i]
    total_matches += row.sum()


accuracy = correct_matches / total_matches if total_matches > 0 else 0
correct_matches,total_matches,accuracy
# Out:
# (915, 1049, 0.8722592945662536)

# %%
first_indices = matching[0]
second_indices = matching[1]
second_array_labels = adata1_df.iloc[second_indices]['celltype'].values

max_index = first_indices.max()
new_labels = np.empty(max_index + 1, dtype=object)

# transfer
new_labels[first_indices] = second_array_labels

adata_2.obs['transferred_labels'] = new_labels

# %%
import matplotlib.colors as mcolors
spot_size = 200

# 将标签转换为字符串
adata_2.obs['transferred_labels'] = adata_2.obs['transferred_labels'].astype(str)

pathology_color = [
    "#1F77B4", "#FF7F0E", "#2CA02C", "#D62728", "#9467BD", "#8C564B",
    "#E377C2", "#7F7F7F", "#BCBD22", "#17BECF", "#AEC7E8", "#FFBB78",
    "#98DF8A", "#FF9896", "#C5B0D5", "#C49C94", "#F7B6D2", "#C7C7C7",
    "#DBDB8D", "#9EDAE5", "#1F9B99", "#FFCD56", "#33A02C", "#FB9A99",
    "#A6CEE3"
]
sc.pl.spatial(adata_2, img_key=None, color=['transferred_labels'], title=[''],
                legend_fontsize=12, show=False, frameon=False, palette=pathology_color,
                spot_size=spot_size)
# Out:
# [<AxesSubplot: xlabel='spatial1', ylabel='spatial2'>]

# %%
first_indices = matching_2[0]
second_indices = matching_2[1]
second_array_labels = adata3_df.iloc[second_indices]['celltype'].values

max_index = first_indices.max()
new_labels = np.empty(max_index + 1, dtype=object)

# transfer
new_labels[first_indices] = second_array_labels

adata_2.obs['transferred_labels_SLAT'] = new_labels

# %%
adata_2.obs['transferred_labels_SLAT'] = adata_2.obs['transferred_labels_SLAT'].astype(str)
sc.pl.spatial(adata_2, img_key=None, color=['transferred_labels_SLAT'], title=[''],
                legend_fontsize=12, show=False, frameon=False, palette=pathology_color,
                spot_size=spot_size)
# Out:
# [<AxesSubplot: xlabel='spatial1', ylabel='spatial2'>]

# %%
spot_size = 200
pathology_color = ["#6D1A9B", "#CB79A6", "#7494D2", "#59BD85", "#56B3E8", "#FDB815", "#F46867"]
sc.pl.spatial(adata_2, img_key=None, color=['ground_truth'], title=[''],
                legend_fontsize=12, show=False, frameon=False, palette=pathology_color,
                spot_size=spot_size)
# Out:
# [<AxesSubplot: xlabel='spatial1', ylabel='spatial2'>]

# %%
adata_1
# Out:
# AnnData object with n_obs × n_vars = 1053 × 166
#     obs: 'ct', 'region', 'Region', 'ground_truth'
#     uns: 'ct_colors', 'region_colors', 'Spatial_Net'
#     obsm: 'spatial', 'scSLAT_bks', 'scSLAT'

# %%
adata_2
# Out:
# AnnData object with n_obs × n_vars = 1049 × 166
#     obs: 'ct', 'region', 'Region', 'ground_truth', 'transferred_labels', 'transferred_labels_SLAT'
#     uns: 'ct_colors', 'region_colors', 'Spatial_Net', 'transferred_labels_colors', 'transferred_labels_SLAT_colors', 'ground_truth_colors'
#     obsm: 'spatial', 'scSLAT_bks', 'scSLAT'

# %%
# adata_1.write('D:\ppppaper\data\Result\STARmap_09.h5ad')

# %%
# adata_2.write('D:\ppppaper\data\Result\STARmap_05.h5ad')
